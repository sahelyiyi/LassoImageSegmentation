# %% [markdown]
# # Primal-dual method for logistic regression

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pygsp as gsp
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from scipy import sparse
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import normalize
from scipy.optimize import minimize
from datetime import datetime
import os

# %% [markdown]
# ## The graph dataset

# %% [markdown]
# Now let $\mathbf{X} = (\mathbf{x}^{(1)}, \ldots, \mathbf{x}^{(N)}) \in \mathbb{R}^{d\times N}$ is the matrix of feature vector with. The learnable parameters $\mathbf{W} = (\mathbf{w}^{(1)}, \ldots, \mathbf{w}^{(N)})
# $. The true labels $y = (y^{(1)}, \ldots, y^{(N)})^T$ and the known labels $y_M$ = $\{y^{(i)}\}_{i \in \mathcal{M}}$, for data points in the training set $\mathcal{M}=\{i_{1},\ldots,i_{M}\}$ of size $M$. The regularization parameter $\lambda$ `reg`.

# %% [markdown]
# ## The logistic network lasso problem
#
# The incidence matrix `D` $\mathbf{D} \in \mathbb{R}^{E\times N}$

# %%
def incident_matrix(graph):
    v1, v2, weights = graph.get_edge_list()
    a= np.append(weights, -weights)
    b = np.append(v1,  v2)
    c = np.append(np.arange(v1.size), np.arange(v1.size))
    D = sparse.coo_matrix((a, (c, b)), shape=(v1.size, graph.N))
    #D = np.zeros((v1.size, graph.N))
    #D[np.arange(v1.size),v1] = weights
    #D[np.arange(v1.size), v2] = - weights
    return D, weights

# %% [markdown]
# The total variation (TV) $ {\rm TV}(\mathbf{W}) = \|\mathbf{W}\|_{\rm TV}$ is the sum of the row norms of the matrix $\mathbf{D} \mathbf{W}^T$

# %%
def TV(D):
    return lambda a : np.sum(np.linalg.norm(D.dot(a.T), axis=1))

# %% [markdown]
# The empirical loss $ {\rm ERM} = (1/M) \sum_{i\in \mathcal{M}} l(y^{(i)} [\mathbf{w}^{(i)}]^T\mathbf{x}^{(i)})$

# %%
def ERM(X, M, y_M):
    return lambda a : (1/np.sum(M)) * np.sum (M* np.log(1 + np.exp(-y_M* np.sum(a*X, axis=0))))

# %% [markdown]
# Objective function of the optimization problem ${\rm obj} = {\rm ERM} + \lambda {\rm TV}$

# %%
def obj_func(D, X, M, y_M, reg):
    return lambda a : ERM(X, M, y_M)(a) + reg* TV(D)(a)

# %% [markdown]
# ## Primal Dual Method:
# Vectoring the graph signal to use the primal-dual method $\mathbf{x} = (\mathbf{x}^{(1)T}, \ldots, \mathbf{x}^{(N)T})^T $ is the matrix of feature vector with. $\mathbf{w} = (\mathbf{w}^{(1)T}, \ldots, \mathbf{w}^{(N)T})^T$

# %% [markdown]
# Now, let consider the intertible diagonal matrix $\mathbf{T} \in \mathbb{R}^{N \times N}$ and $\mathbf{\Sigma} \in \mathbb{R}^{E \times E}$. Initialize the values for variables

# %%
def diag_matrices(graph, D, weights):
    tau = 1/graph.dw
    T = sparse.diags(tau, 0)
    Sigma = sparse.diags(0.9/(2*weights), 0)
    #T =  np.diag(1/graph.dw)
    #Sigma = 0.9*np.diag(1/(2*weights))
    SD = Sigma.dot(D)
    TDT = T.dot(D.T)
    return tau, T, Sigma, SD, TDT

# %% [markdown]
# ### The primal dual update

# %%
def primal_dual(g_params, X, y, M, init_w=None, num_iter=100, reg = 1e-1, print_every=0, inexact_update=True):
    D, tau, T, Sigma, SD, TDT = g_params
    sizeM = np.sum(M)
    y_M = M * y
    obj = obj_func(D, X, M, y_M, reg)
    d, N = X.shape
    E = D.shape[0]
    w = np.zeros((num_iter,d,N))
    if init_w is not None:
        w[0,:,:] = init_w
    u = np.zeros((num_iter, d, E))
    running_average = np.zeros((num_iter,d,N))
    obj_hist = np.zeros(num_iter)
    obj_hist_avg = np.zeros(num_iter)
    obj_hist_avg[0]= obj(running_average[0]) 
    obj_hist[0]= obj(w[0]) 
    non_acc_hist = np.zeros(num_iter)
    acc_hist = np.zeros(num_iter)
    sampling_indices = np.where(M>0)[0]
    for idx in range(1, num_iter):
        w_hat = w[idx-1] - TDT.dot(u[idx-1].T).T
        w[idx] = np.copy(w_hat)
        for i in sampling_indices:
            if inexact_update:
                phi_i = lambda vu : w_hat[:,i] + tau[i] * (y[i] * X[:,i])/(1+np.exp(y[i]*np.sum(vu*X[:,i]) )) /sizeM 
                beta_i = tau[i] * np.power(np.linalg.norm(X[:,i]),2) /sizeM
                lp = int(np.ceil(2 *np.log(idx)/ np.log(1/beta_i)))
                for j in range(lp):
                    w[idx][:,i]= phi_i(w[idx][:,i])
            else:
                equ_18 = lambda vw: np.log(1+ np.exp(-vw @ (y[i] * X[:,i]))) / sizeM + 1/(2 * tau[i]) * np.linalg.norm(vw - w_hat[:,i])**2
                res = minimize(equ_18, w_hat[:,i], method='BFGS')
                w[idx][:,i] = res.x


        u_hat  = u[idx-1] + SD.dot((2*w[idx] - w[idx-1]).T).T
        b = np.linalg.norm(u_hat, axis=0)
        for j in range(b.shape[0]):
            b[j] = (1- reg/b[j]) if b[j]  > reg else 0
        u[idx] = u_hat - b*u_hat
        running_average[idx] = (running_average[idx-1]*(idx-1) + w[idx])/idx
        obj_hist_avg[idx]= obj(running_average[idx])    
        obj_hist[idx]= obj(w[idx])
        non_acc_hist[idx], acc_hist[idx] = accuracy(running_average[idx], X, y, M)
        if print_every !=0 and idx%print_every==0:
            print('loss after %2.0f iteration = %2.5f' % (idx, obj_hist_avg[idx]))
    return w, running_average, obj_hist, obj_hist_avg, non_acc_hist, acc_hist

# %% [markdown]
# ### Plot the result

# %%
def plot_results(X, y, w, obj_hist_avg, reg, prefix ='chain', is_saved=False):
    d, N = X.shape
    num_iter = len(obj_hist_avg)
    x_range = np.arange(1,num_iter)
    f = plt.figure()
    avg_line, = plt.plot(obj_hist_avg[1:], 'r--', label='average weight')
    plt.xlabel('Iteration')
    plt.ylabel('objective value')
    plt.show()
    if is_saved:
        f.savefig('convergence_' +prefix+ '_%1.e.pdf' % reg, bbox_inches='tight')

    f = plt.figure()
    plt.title(r'the recovered weight, $\lambda$ = %1.e' % reg)
    plt.plot(w[num_iter-1,0:].T)
    plt.xlabel('node index')
    plt.show()
    if is_saved:
        f.savefig('weights_' +prefix+ '_%1.e.pdf' % reg, bbox_inches='tight')
    
    f = plt.figure()
    plt.title(r'the recovered labels, $\lambda$ = %1.e' % reg)
    recovered_line, = plt.plot(np.sign(np.sum(w[num_iter-1]*X, axis=0)), 'bs', label='estimated labels')
    true_line, = plt.plot(y, 'r^', label='true labels')
    plt.legend(handles=[recovered_line, true_line])
    plt.xlabel('node index')
    plt.show()
    if is_saved:
        f.savefig('labels_' +prefix+ '_%1.e.pdf' % reg, bbox_inches='tight')

# %%
def plot_convergence(obj_hist_avg, reg, prob, prefix ='chain', is_saved=False):
    num_iter = len(obj_hist_avg)
    x_range = np.arange(0,num_iter)
    for pr in range(len(prob)):
        f = plt.figure()
        lines = [None]*len(reg)
        lbd_str = ['$\lambda$= %1.e' %i for i in reg]
        for i in range(len(reg)):
            lines[i], = plt.plot(x_range, obj_hist_avg[0:,i,pr])
        plt.legend(lines,  lbd_str)
        plt.xlabel('Iteration', fontsize=11)
        plt.ylabel('objective value', fontsize=11)
        plt.title('convergence for prob=%f' % prob[pr])
        plt.show()
        if is_saved:
            f.savefig('convergence_prob_' + str(pr) + prefix + '.pdf', bbox_inches='tight')
    # for r in range(len(reg)):
    #     f = plt.figure()
    #     lines = [None]*len(prob)
    #     lbd_str = ['prob= %f' %i for i in prob]
    #     for i in range(len(prob)):
    #         lines[i], = plt.plot(x_range, obj_hist_avg[0:,r,i])
    #     plt.legend(lines,  lbd_str)
    #     plt.xlabel('Iteration', fontsize=11)
    #     plt.ylabel('objective value', fontsize=11)
    #     plt.title('convergence for $\lambda$= %1.e' % reg[r])
    #     plt.show()
    #     if is_saved:
    #         f.savefig('convergence_reg_' + str(r) + prefix + '.pdf', bbox_inches='tight')

# %%
def plot_convergence_by_accuracy(accuracy_hist, opt_acc, reg, prob, prefix ='chain', is_saved=False, nonlabled=False):
    num_iter = len(accuracy_hist)
    x_range = np.arange(0,num_iter)
    for pr in range(len(prob)):
        f = plt.figure()
        lines = [None]*(len(reg) + 1)
        lbd_str = ['$\lambda$= %1.e' %i for i in reg]
        lbd_str.append('optimal accuracy')
        for i in range(len(reg)):
            lines[i], = plt.plot(x_range, accuracy_hist[0:,i, pr])
        lines[len(reg)], = plt.plot(x_range, opt_acc*np.ones(num_iter), '--')
        plt.legend(lines,  lbd_str)
        plt.xlabel('Iteration', fontsize=11)
        ylabel = 'accuracy'
        pref = prefix

        if nonlabled:
            ylabel = 'nonlabeled node accuracy'
            pref = 'non' + pref
        plt.ylabel(ylabel, fontsize=11)
        plt.title('nonlabeled node accuracy for prob=%f' % prob[pr])
        plt.show()
        if is_saved:
            f.savefig('convergence_accuracy_prob' + str(prob) + pref + '.pdf', bbox_inches='tight')
    # for r in range(len(reg)):
    #     f = plt.figure()
    #     lines = [None]*(len(prob) + 1)
    #     lbd_str = ['prob= %f' %i for i in prob]
    #     lbd_str.append('optimal accuracy')
    #     for i in range(len(prob)):
    #         lines[i], = plt.plot(x_range, accuracy_hist[0:,r,i])
    #     lines[len(prob)], = plt.plot(x_range, opt_acc*np.ones(num_iter), '--')
    #     plt.legend(lines,  lbd_str)
    #     plt.xlabel('Iteration', fontsize=11)
    #     ylabel = 'accuracy'
    #     pref = prefix
    # 
    #     if nonlabled:
    #         ylabel = 'nonlabeled node accuracy'
    #         pref = 'non' + pref
    #     plt.ylabel(ylabel, fontsize=11)
    #     plt.title('nonlabeled node accuracy for $\lambda$= %1.e' % reg[r])
    #     plt.show()
    #     if is_saved:
    #         f.savefig('convergence_accuracy_reg' + str(r) + pref + '.pdf', bbox_inches='tight')

# %% [markdown]
# The accuracy should be $(1/ N)\sum_i 1_{y^{(i)}}(sign(\mathbf{w}^{(i)T}\mathbf{x}{(i)})) $

# %%
def compute_recovered_labels(W, X):
    return 2*(np.sum(W*X, axis=0)>0) -1

# %%
def accuracy(W, X, y, M=None):
    N = y.shape[0]
    non_acc = None
    if M is not None:
        non_acc =   np.sum((1-M)* (compute_recovered_labels(W, X)==y))/(N-np.sum(M))
    acc_ = (1/N) * np.sum(compute_recovered_labels(W, X)==y)
    return non_acc, acc_

# %%
def print_accuracy(w, X, y, M,reg):
    N = y.shape[0]
    non_acc, acc_ = accuracy(w, X, y, M)
    print('sampling ratio = ', np.sum(M)/N , ',reg = ', reg, ', unlabeled-node accuracy = ', non_acc)
    print('labeled-node accuracy = ', np.sum(M* (compute_recovered_labels(w, X)==y))/(np.sum(M)))
    print('the aggregated accuracy = ', acc_)
    return non_acc, acc_

# %%
def run_experiments(g_params, X, y, num_iter, reg, prob, init_w=None, M=None, print_every=0, compare_with_lr = False):
    if M is None:
        N = X.shape[1]
        M = np.zeros(N)
        while True:
            M = np.array([1 if np.random.rand(1)<prob else 0 for k in range(N)])
            if np.sum(M)>0:
                break
    w, running_average, obj_hist, obj_hist_avg, non_acc_hist, acc_hist = primal_dual(g_params, X, y, M, init_w, num_iter, reg,print_every=print_every, inexact_update=False)
    if compare_with_lr:
        lr_classifer = lr_clsfier(X,y,M)
        print('the accuracy by vanila logistic regression ',lr_classifer.score(X.T, y))
        print('the coefficient by vanila logistic regression ', lr_classifer.coef_)
        np.save('vanila_w_%f_%f' % (reg, prob), lr_classifer.coef_)
#         print('the coefficient by  lnlasso ', w[num_iter-1].T)
    non_acc, acc_ = print_accuracy(running_average[num_iter-1], X, y, M, reg)
    print('-----------------')
    return w, running_average, obj_hist, obj_hist_avg, non_acc, acc_, non_acc_hist, acc_hist

# %%
def lr_clsfier(X,y,M):
    lr_classifer = LogisticRegression(random_state=0, solver='lbfgs', multi_class='ovr', fit_intercept=False, C=1000)
    lr_classifer = lr_classifer.fit(X.T, y, sample_weight = M)
    return lr_classifer

# %%
def train(graph, X, y, opt_acc, num_iter, reg, prob, num_exps, init_w=None, M=None, is_plot=False, prefix="chain2", is_saved=False, print_every=0, compare_with_lr=False):
    D, weights = incident_matrix(graph)
    tau, T, Sigma, SD, TDT = diag_matrices(graph, D, weights)
    g_params = D, tau, T, Sigma, SD, TDT
    if np.isscalar(reg):
        reg = np.array([reg])
    if np.isscalar(prob):
        prob = np.array([prob])
    acc = np.zeros((len(reg), num_exps, len(prob)))
    non_acc = np.zeros((len(reg), num_exps, len(prob)))
    
    convergence_hist = np.zeros((num_iter, len(reg), len(prob)))
    acc_hist = np.zeros((num_iter, len(reg), len(prob)))
    non_acc_hist = np.zeros((num_iter, len(reg), len(prob)))
    r_w = None
    
    for r in range(len(reg)):
        for i in range(len(prob)):
            for j in range(num_exps):
                w, running_average, obj_hist, obj_hist_avg, non_acc_, acc_, non_acc_hist_, acc_hist_ = run_experiments(g_params, X, y, num_iter, reg[r], prob[i], init_w, M, print_every=print_every,compare_with_lr=compare_with_lr)
                np.save('./weights/w_%s_%f_%f_%d' % (prefix, reg[r], prob[i], j), w[-1])
                r_w = w[-1]
                #M = np.zeros(N)
                #M = np.array([1 if np.random.rand(1)<prob[i] else 0 for k in range(N)])
                #w, running_average, obj_hist, obj_hist_avg = primal_dual(graph, X, y, M, num_iter, reg[r],print_every=print_every)
                if is_plot and j==0:
                    convergence_hist[:,r,i] = np.copy(obj_hist_avg)
                    acc_hist[:,r,i] = np.copy(acc_hist_)
                    non_acc_hist[:,r,i] = np.copy(non_acc_hist_)
#                     plot_gray_w(w[num_iter-1])
                acc[r,j,i] = acc_
                non_acc[r,j,i] = non_acc_
    if is_plot:
        plot_convergence(convergence_hist, reg, prob, prefix, is_saved)
        plot_convergence_by_accuracy(acc_hist, opt_acc, reg, prob, prefix, is_saved, nonlabled=False)
        plot_convergence_by_accuracy(non_acc_hist, opt_acc, reg, prob, prefix, is_saved, nonlabled=True)
    return non_acc, acc, r_w

# %%
def plot_gray_w(w):
    w2 = np.linalg.norm(w, axis=0)
    k = int(np.sqrt(w2.shape[0]))
    plt.imshow(np.reshape(w2, (k, k)))
    plt.show()

# %%
def fb_segment(graph, X, y, num_iter, reg, prob, img_size, print_every=0):
    w, running_average, obj_hist, obj_hist_avg, acc_ = run_experiments(graph, X, y, num_iter, reg, prob, print_every=print_every)
    recovered_labels = compute_recovered_labels(w[num_iter-1],X)
    return np.reshape(recovered_labels, (img_size[0],img_size[1]))

# %%
def plot_accuracy(acc, prob, reg, is_saved=False, prefix='chain2'):
    fig = plt.figure()
    plt.title(r'Accuracy, $\lambda$ = %1.e' % reg)
    plt.boxplot(acc)
    plt.xticks(np.arange(len(prob))+1, np.around(prob, decimals=2))
    plt.xlabel(r'Labeling rate $p$')
    plt.show()
    if is_saved:
        fig.savefig('accuracy_'+prefix+'_%1.e.pdf' % reg, bbox_inches='tight')

# %% [markdown]
# Now, let run the algorithm for different choices of graph

# %%
DEBUG_MODE = 0
PAPER_MODE = 1

FLAG_RUNNING = DEBUG_MODE
intercluster_weight = 1
intracluster_weight = 100
if FLAG_RUNNING==DEBUG_MODE:
    num_iter = 15
    num_exps = 3
    prob = np.arange(0.1,1,0.2)
    reg= np.concatenate((np.logspace(-5,-1,5), np.arange(1)))
elif FLAG_RUNNING==PAPER_MODE:
    num_iter = 40
    num_exps = 50
    prob = np.arange(0.1,1,0.1)
    reg= np.logspace(-5,-1,5)
print(num_iter, num_exps, prob, reg)
# Out:
# 15 3 [0.1 0.3 0.5 0.7 0.9] [1.e-05 1.e-04 1.e-03 1.e-02 1.e-01 0.e+00]

# %%
TXT_PROP = 'prob'
TXT_REG = 'reg'
TXT_ACC = '_acc'
def save_accuracy(acc, prob, reg, mat_name, mode=DEBUG_MODE):
    import scipy
    if mode==PAPER_MODE:
        scipy.io.savemat(mat_name, mdict = {mat_name+ TXT_ACC: acc, TXT_PROP : prob, TXT_REG : reg})

# %%
def plot_acc_results(acc, prob, reg, mat_name, mode=DEBUG_MODE):
    if mode==PAPER_MODE:
        acc_dict = scipy.io.loadmat(mat_name)
        for i in range(acc_dict[TXT_REG].shape[1]):
            plot_accuracy(acc_dict[mat_name+ TXT_ACC][i], acc_dict[TXT_PROP][0], acc_dict[TXT_REG][0][i], is_saved=True, prefix=mat_name)
    else:
        for i in range(len(reg)):
            plot_accuracy(acc[i], prob, reg[i])

# %%
def plot_curves_by_prob(acc, opt_acc, prob, reg, prefix, mode=DEBUG_MODE):
    fig = plt.figure()
    plt.title(r'Accuracy')
    acc_ = np.mean(acc, axis=1)
    lines = [None]*(len(reg)+1)
    lbd_str = ['$\lambda$= %1.e' %i for i in reg]
    lbd_str.append('optimal accuracy')
    for i in range(len(reg)):
        lines[i], = plt.plot(prob, acc_[i])
    lines[len(reg)],  = plt.plot(prob, opt_acc*np.ones(len(prob)), '--')
    plt.legend(lines,  lbd_str)
    plt.xlabel('labeling rate p')
    plt.show()
    if mode==PAPER_MODE:
        fig.savefig('accuracy_' + prefix + '.pdf', bbox_inches='tight')

# %%
def plot_curves_by_reg(acc, prob, reg, prefix, mode=DEBUG_MODE):
    fig = plt.figure()
    plt.title(r'Accuracy')
    acc_ = np.mean(acc, axis=1)
    lines = [None]*len(prob)
    prob_str = ['$p$= %.1f' %i for i in prob]
    for i in range(len(prob)):
        lines[i], = plt.plot(reg, acc_[:,i])
    plt.legend(lines,  prob_str)
    plt.xlabel('regularizer parameter $\lambda$')
    plt.show()
    if mode==PAPER_MODE:
        fig.savefig('accuracy_' + prefix + '.pdf', bbox_inches='tight')

# %% [markdown]
# # Foreground/background segmentation

# %% [markdown]
# Reading image and the segmentation of its pixels data.

# %%
import pandas as pd
import imageio
import math
import cv2

img_path = os.path.join('./frames/' , "frame10.jpg")

img = cv2.imread(img_path)
bw_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

treshhold = 170
h, w, _ = img.shape
lables = np.zeros((h, w))
for y in range(h):
    for x in range(w):
        if bw_img[y, x] >= treshhold:
            lables[y, x] = 1


img_labels = 2*lables-1
img_labels = img_labels.astype(int)

# %%
def show_img_with_label(img, labels=None, is_saved = False, img_file_name=None):
    fig = plt.figure()
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    plt.set_cmap('hot')
    if labels is not None:
        img2 = np.zeros_like(img)
        for j in np.arange(img.shape[2]):
            img2[:,:,j] = img[:,:,j]* (labels+1)/2
        ax.imshow(img2, aspect='equal')
    else:
        ax.imshow(img, aspect='equal')
    if is_saved:
        plt.savefig(img_file_name+'_recovered.pdf')

# %%
show_img_with_label(img)

# %%
show_img_with_label(img,img_labels)

# %% [markdown]
# The following block contains the required functions for making an image graph.

# %%
# some constants
WIDTH = 4.0

# convolve image with gaussian filter
def smooth(src, sigma):
    mask = make_fgauss(sigma)
    mask = normalize(mask)
    tmp = convolve_even(src, mask)
    dst = convolve_even(tmp, mask)
    return dst


# gaussian filter
def make_fgauss(sigma):
    sigma = max(sigma, 0.01)
    length = int(math.ceil(sigma * WIDTH)) + 1
    mask = np.zeros(shape=length, dtype=float)
    for i in range(length):
        mask[i] = math.exp(-0.5 * math.pow(i / sigma, i / sigma))
    return mask


# normalize mask so it integrates to one
def normalize(mask):
    sum = 2 * np.sum(np.absolute(mask)) + abs(mask[0])
    return np.divide(mask, sum)


# convolve src with mask.  output is flipped!
def convolve_even(src, mask):
    output = np.zeros(shape=src.shape, dtype=float)
    height, width = src.shape
    length = len(mask)

    for y in range(height):
        for x in range(width):
            sum = float(mask[0] * src[y, x])
            for i in range(1, length):
                sum += mask[i] * (src[y, max(x - i, 0)] + src[y, min(x + i, width - 1)])
            output[y, x] = sum
    return output


# returns square of a number
def square(value):
    return value * value


# dissimilarity measure between pixels
def diff(red_band, green_band, blue_band, x1, y1, x2, y2):
    result = math.sqrt(
        square(red_band[y1, x1] - red_band[y2, x2]) + square(green_band[y1, x1] - green_band[y2, x2]) + square(
            blue_band[y1, x1] - blue_band[y2, x2]))
    return result

# %% [markdown]
# Making the graph of image.

# %%
def _get_image_graph(in_image, lables, sigma=0.5):
    height, width, band = in_image.shape
    smooth_red_band = smooth(in_image[:, :, 0], sigma)
    smooth_green_band = smooth(in_image[:, :, 1], sigma)
    smooth_blue_band = smooth(in_image[:, :, 2], sigma)

    # build graph
    uc_X = []
    uc_y = []
    row = []
    col = []
    data = []
    for y in range(height):
        for x in range(width):

            node_num = int(y * width + x)
            uc_X.append(in_image[y, x])
            uc_y.append(lables[y, x])

            if x < width - 1:
                neigh_num = int(y * width + (x + 1))
                weight = diff(smooth_red_band, smooth_green_band, smooth_blue_band, x, y, x + 1, y)

                row.append(node_num)
                col.append(neigh_num)
                data.append(weight)

                row.append(neigh_num)
                col.append(node_num)
                data.append(weight)

            if y < height - 1:
                neigh_num = int((y + 1) * width + x)
                weight = diff(smooth_red_band, smooth_green_band, smooth_blue_band, x, y, x, y + 1)

                row.append(node_num)
                col.append(neigh_num)
                data.append(weight)

                row.append(neigh_num)
                col.append(node_num)
                data.append(weight)

            if (x < width - 1) and (y < height - 2):
                neigh_num = int((y + 1) * width + (x + 1))
                weight = diff(smooth_red_band, smooth_green_band, smooth_blue_band, x, y, x + 1, y + 1)
                row.append(node_num)
                col.append(neigh_num)
                data.append(weight)

                row.append(neigh_num)
                col.append(node_num)
                data.append(weight)

            if (x < width - 1) and (y > 0):
                neigh_num = int((y - 1) * width + (x + 1))
                weight = diff(smooth_red_band, smooth_green_band, smooth_blue_band, x, y, x + 1, y - 1)

                row.append(node_num)
                col.append(neigh_num)
                data.append(weight)

                row.append(neigh_num)
                col.append(node_num)
                data.append(weight)

    uc_adj = sparse.coo_matrix((data, (row, col)), shape=(len(uc_X), len(uc_X)))
    
    uc_graph = gsp.graphs.Graph(W=uc_adj)

    # TODO FIX THIS
    uc_opt_acc = 1.0

    uc_X = np.array(uc_X).T
    uc_y = np.array(uc_y)
    np.save('uc_X', uc_X)
    np.save('uc_y', uc_y)
    np.save('data', np.array(data))
    np.save('row', np.array(row))
    np.save('col', np.array(col))

    return uc_graph, uc_opt_acc, uc_y, uc_X

# %%
# prob = [0.01, 0.1, 0.5, 1.0]
import datetime
prob = [0.1]
reg = [0.001]
init_w = None
for i in range(20):
    img_name = "frame%d" % i
    img_path = os.path.join('./frames/' , img_name + '.jpg')

    img = cv2.imread(img_path)
    bw_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

    lables = np.load('./new_labels/label%d.npy' % i)
    img_labels = 2*lables-1
    img_labels = img_labels.astype(int)
    
    print(i, datetime.datetime.now(), 'use zero lables')
    uc_graph, uc_opt_acc, uc_y, uc_X = _get_image_graph(img, img_labels)
    uc_non_acc, uc_acc, w = train(uc_graph, uc_X, uc_y, uc_opt_acc, 10, reg=reg, prob=prob, num_exps=1, init_w=None, M=None, is_plot=True, prefix=img_name,
                                   is_saved=True, compare_with_lr=True)
    
    print(i, datetime.datetime.now(), 'use previous lables')
    uc_graph, uc_opt_acc, uc_y, uc_X = _get_image_graph(img, img_labels)
    uc_non_acc, uc_acc, w = train(uc_graph, uc_X, uc_y, uc_opt_acc, 10, reg=reg, prob=prob, num_exps=1, init_w=init_w, M=None, is_plot=True, prefix=img_name,
                                   is_saved=True, compare_with_lr=True)
    init_w = w
    print('------------------------------------\n')
# Out:
# 0 2019-10-25 15:34:50.683383 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8416398321623731
# the coefficient by vanila logistic regression  [[ 0.0623288   0.13534642 -0.19358982]]
# sampling ratio =  0.09941695940671351 ,reg =  0.001 , unlabeled-node accuracy =  0.9848280046699732
# labeled-node accuracy =  0.9957794518194979
# the aggregated accuracy =  0.9859167642466823
# -----------------
# 0 2019-10-25 15:40:55.007483 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8427961553473848
# the coefficient by vanila logistic regression  [[ 0.06491131  0.13303142 -0.19387359]]
# sampling ratio =  0.1002903005464481 ,reg =  0.001 , unlabeled-node accuracy =  0.9848891973894346
# labeled-node accuracy =  0.9958648536887937
# the aggregated accuracy =  0.9859899492583919
# -----------------
# ------------------------------------
#
# 1 2019-10-25 15:48:25.236834 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8328210382513661
# the coefficient by vanila logistic regression  [[ 0.06135173  0.13033755 -0.1876911 ]]
# sampling ratio =  0.09977800546448087 ,reg =  0.001 , unlabeled-node accuracy =  0.9836891867356423
# labeled-node accuracy =  0.9961125644849759
# the aggregated accuracy =  0.9849287665886026
# -----------------
# 1 2019-10-25 15:55:35.735372 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8328478727556596
# the coefficient by vanila logistic regression  [[ 0.05803317  0.12815504 -0.18228109]]
# sampling ratio =  0.1001585675253708 ,reg =  0.001 , unlabeled-node accuracy =  0.9686631622038535
# labeled-node accuracy =  0.9803931120150036
# the aggregated accuracy =  0.9698380171740828
# -----------------
# ------------------------------------
#
# 2 2019-10-25 16:02:24.065155 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8315207845433256
# the coefficient by vanila logistic regression  [[ 0.05745912  0.12626753 -0.17973487]]
# sampling ratio =  0.09951209992193599 ,reg =  0.001 , unlabeled-node accuracy =  0.9848968379532304
# labeled-node accuracy =  0.9961512061188469
# the aggregated accuracy =  0.9860167837626854
# -----------------
# 2 2019-10-25 16:09:22.503975 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8307377049180328
# the coefficient by vanila logistic regression  [[ 0.05658344  0.12415398 -0.17701852]]
# sampling ratio =  0.09978776346604215 ,reg =  0.001 , unlabeled-node accuracy =  0.9578607915667385
# labeled-node accuracy =  0.9705659454834372
# the aggregated accuracy =  0.9591286104605776
# -----------------
# ------------------------------------
#
# 3 2019-10-25 16:15:21.153452 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8233411397345823
# the coefficient by vanila logistic regression  [[ 0.05496142  0.12092517 -0.17211209]]
# sampling ratio =  0.10047326307572209 ,reg =  0.001 , unlabeled-node accuracy =  0.9834487733705055
# labeled-node accuracy =  0.9958723838197445
# the aggregated accuracy =  0.9846970140515222
# -----------------
# 3 2019-10-25 16:20:18.472136 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8237314597970335
# the coefficient by vanila logistic regression  [[ 0.05541291  0.12022096 -0.17183743]]
# sampling ratio =  0.10020979703356753 ,reg =  0.001 , unlabeled-node accuracy =  0.9370516372864262
# labeled-node accuracy =  0.9530162130580846
# the aggregated accuracy =  0.9386514441842311
# -----------------
# ------------------------------------
#
# 4 2019-10-25 16:24:47.130357 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8225190281030444
# the coefficient by vanila logistic regression  [[ 0.05489554  0.11930253 -0.17051683]]
# sampling ratio =  0.09990485948477752 ,reg =  0.001 , unlabeled-node accuracy =  0.9818737177037513
# labeled-node accuracy =  0.9957268087807974
# the aggregated accuracy =  0.9832577088212334
# -----------------
# 4 2019-10-25 16:29:15.255165 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8223653395784544
# the coefficient by vanila logistic regression  [[ 0.05395873  0.11871186 -0.16900631]]
# sampling ratio =  0.10001707650273224 ,reg =  0.001 , unlabeled-node accuracy =  0.9260681826190431
# labeled-node accuracy =  0.943144954754994
# the aggregated accuracy =  0.9277761514441842
# -----------------
# ------------------------------------
#
# 5 2019-10-25 16:33:41.794965 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.819916081186573
# the coefficient by vanila logistic regression  [[ 0.05504949  0.11790796 -0.16914998]]
# sampling ratio =  0.1002805425448868 ,reg =  0.001 , unlabeled-node accuracy =  0.9808575077342718
# labeled-node accuracy =  0.9959374315809959
# the aggregated accuracy =  0.9823697306791569
# -----------------
# 5 2019-10-25 16:38:21.808543 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.81935987509758
# the coefficient by vanila logistic regression  [[ 0.05464162  0.11851727 -0.1694639 ]]
# sampling ratio =  0.09988778298204527 ,reg =  0.001 , unlabeled-node accuracy =  0.9104245827619291
# labeled-node accuracy =  0.9307380452303033
# the aggregated accuracy =  0.9124536494925839
# -----------------
# ------------------------------------
#
# 6 2019-10-25 16:42:52.249636 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8266661787665887
# the coefficient by vanila logistic regression  [[ 0.04269481  0.11903257 -0.15952954]]
# sampling ratio =  0.09965359094457456 ,reg =  0.001 , unlabeled-node accuracy =  0.9844528138293549
# labeled-node accuracy =  0.9970869033047736
# the aggregated accuracy =  0.9857118462138954
# -----------------
# 6 2019-10-25 16:47:21.441297 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.828307962529274
# the coefficient by vanila logistic regression  [[ 0.04470296  0.12267107 -0.16470331]]
# sampling ratio =  0.100426912568306 ,reg =  0.001 , unlabeled-node accuracy =  0.8926951102770689
# labeled-node accuracy =  0.9179925668618067
# the aggregated accuracy =  0.8952356557377049
# -----------------
# ------------------------------------
#
# 7 2019-10-25 16:51:47.505263 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8217725409836065
# the coefficient by vanila logistic regression  [[ 0.04244223  0.1201187  -0.15991649]]
# sampling ratio =  0.09983411397345823 ,reg =  0.001 , unlabeled-node accuracy =  0.9838345131112533
# labeled-node accuracy =  0.9964812823770892
# the aggregated accuracy =  0.9850970921155348
# -----------------
# 7 2019-10-25 16:56:13.942100 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8216822794691647
# the coefficient by vanila logistic regression  [[ 0.04229159  0.11956259 -0.15917822]]
# sampling ratio =  0.10039032006245122 ,reg =  0.001 , unlabeled-node accuracy =  0.8894914960083304
# labeled-node accuracy =  0.9107455287713841
# the aggregated accuracy =  0.8916251951600312
# -----------------
# ------------------------------------
#
# 8 2019-10-25 17:01:36.332509 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8268613387978142
# the coefficient by vanila logistic regression  [[ 0.04769821  0.12208814 -0.16695681]]
# sampling ratio =  0.10025370804059329 ,reg =  0.001 , unlabeled-node accuracy =  0.9840194781250677
# labeled-node accuracy =  0.996690675491532
# the aggregated accuracy =  0.9852898126463701
# -----------------
# 8 2019-10-25 17:06:27.753068 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8268613387978142
# the coefficient by vanila logistic regression  [[ 0.04623984  0.12020065 -0.16379792]]
# sampling ratio =  0.09940964090554255 ,reg =  0.001 , unlabeled-node accuracy =  0.8834764471652626
# labeled-node accuracy =  0.9086625766871166
# the aggregated accuracy =  0.8859801912568306
# -----------------
# ------------------------------------
#
# 9 2019-10-25 17:11:00.881675 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8227751756440281
# the coefficient by vanila logistic regression  [[ 0.04697141  0.12123173 -0.16490099]]
# sampling ratio =  0.10067086260733801 ,reg =  0.001 , unlabeled-node accuracy =  0.9827778425782511
# labeled-node accuracy =  0.9962439721811617
# the aggregated accuracy =  0.9841334894613584
# -----------------
# 9 2019-10-25 17:16:15.668027 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8227629781420766
# the coefficient by vanila logistic regression  [[ 0.04626236  0.1206397  -0.16367047]]
# sampling ratio =  0.09960480093676816 ,reg =  0.001 , unlabeled-node accuracy =  0.8783386165975778
# labeled-node accuracy =  0.9000734753857458
# the aggregated accuracy =  0.8805035128805621
# -----------------
# ------------------------------------
#
# 10 2019-10-25 17:20:51.765988 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8224702380952381
# the coefficient by vanila logistic regression  [[ 0.05021878  0.11701284 -0.16408724]]
# sampling ratio =  0.10006342701014832 ,reg =  0.001 , unlabeled-node accuracy =  0.9826322437937447
# labeled-node accuracy =  0.9963674484372714
# the aggregated accuracy =  0.9840066354410617
# -----------------
# 10 2019-10-25 17:25:35.783669 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8226239266198283
# the coefficient by vanila logistic regression  [[ 0.04953513  0.11970996 -0.16578547]]
# sampling ratio =  0.10009270101483216 ,reg =  0.001 , unlabeled-node accuracy =  0.8698636449890211
# labeled-node accuracy =  0.8965634901291738
# the aggregated accuracy =  0.8725361046057767
# -----------------
# ------------------------------------
#
# 11 2019-10-25 17:30:21.346731 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8231947697111631
# the coefficient by vanila logistic regression  [[ 0.04578387  0.11740321 -0.16007798]]
# sampling ratio =  0.10110265417642467 ,reg =  0.001 , unlabeled-node accuracy =  0.9815863176977605
# labeled-node accuracy =  0.9965013029630344
# the aggregated accuracy =  0.983094262295082
# -----------------
# 11 2019-10-25 17:35:10.634656 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8234728727556596
# the coefficient by vanila logistic regression  [[ 0.04479094  0.1170082  -0.15863924]]
# sampling ratio =  0.09999024199843871 ,reg =  0.001 , unlabeled-node accuracy =  0.858155432437414
# labeled-node accuracy =  0.8859178296086659
# the aggregated accuracy =  0.8609314012490242
# -----------------
# ------------------------------------
#
# 12 2019-10-25 17:40:16.204905 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8410543520686963
# the coefficient by vanila logistic regression  [[ 0.04328736  0.13331121 -0.17380069]]
# sampling ratio =  0.09958528493364559 ,reg =  0.001 , unlabeled-node accuracy =  0.9831237232388146
# labeled-node accuracy =  0.997378864337857
# the aggregated accuracy =  0.9845433255269321
# -----------------
# 12 2019-10-25 17:46:13.162286 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.840564012490242
# the coefficient by vanila logistic regression  [[ 0.04480756  0.1347568  -0.17687704]]
# sampling ratio =  0.09950722092115535 ,reg =  0.001 , unlabeled-node accuracy =  0.8705361254842467
# labeled-node accuracy =  0.9012012748222603
# the aggregated accuracy =  0.8735875292740047
# -----------------
# ------------------------------------
#
# 13 2019-10-25 17:52:24.399453 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8404176424668228
# the coefficient by vanila logistic regression  [[ 0.04275401  0.13354392 -0.17339517]]
# sampling ratio =  0.10002683450429352 ,reg =  0.001 , unlabeled-node accuracy =  0.9819064992938791
# labeled-node accuracy =  0.996561227227276
# the aggregated accuracy =  0.9833723653395785
# -----------------
# 13 2019-10-25 17:57:42.680461 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8401639344262295
# the coefficient by vanila logistic regression  [[ 0.04357863  0.13545026 -0.17593831]]
# sampling ratio =  0.10085382513661202 ,reg =  0.001 , unlabeled-node accuracy =  0.8696558123382296
# labeled-node accuracy =  0.9037056746166127
# the aggregated accuracy =  0.8730898711943794
# -----------------
# ------------------------------------
#
# 14 2019-10-25 18:02:35.603360 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8351361241217798
# the coefficient by vanila logistic regression  [[ 0.04709057  0.13122326 -0.17471943]]
# sampling ratio =  0.10067818110850897 ,reg =  0.001 , unlabeled-node accuracy =  0.9820751390207514
# labeled-node accuracy =  0.9971892415798401
# the aggregated accuracy =  0.9835967993754879
# -----------------
# 14 2019-10-25 18:07:20.860968 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8352922521467604
# the coefficient by vanila logistic regression  [[ 0.04700286  0.1282478  -0.17176755]]
# sampling ratio =  0.09984631147540983 ,reg =  0.001 , unlabeled-node accuracy =  0.8687339257597069
# labeled-node accuracy =  0.8982139803073615
# the aggregated accuracy =  0.871677400468384
# -----------------
# ------------------------------------
#
# 15 2019-10-25 18:11:57.197894 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8413300156128025
# the coefficient by vanila logistic regression  [[ 0.0534951   0.13478419 -0.18460691]]
# sampling ratio =  0.10072453161592505 ,reg =  0.001 , unlabeled-node accuracy =  0.9805035387691214
# labeled-node accuracy =  0.9961975344522754
# the aggregated accuracy =  0.9820843091334894
# -----------------
# 15 2019-10-25 18:18:19.761177 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8405835284933646
# the coefficient by vanila logistic regression  [[ 0.0496018   0.13102125 -0.17724849]]
# sampling ratio =  0.09944623341139734 ,reg =  0.001 , unlabeled-node accuracy =  0.8624615676341916
# labeled-node accuracy =  0.893855022691034
# the aggregated accuracy =  0.8655835284933645
# -----------------
# ------------------------------------
#
# 16 2019-10-25 18:23:53.917481 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8384099336455894
# the coefficient by vanila logistic regression  [[ 0.05299803  0.12896233 -0.17817297]]
# sampling ratio =  0.09977312646370023 ,reg =  0.001 , unlabeled-node accuracy =  0.9785892943762008
# labeled-node accuracy =  0.9962590772390523
# the aggregated accuracy =  0.9803522638563622
# -----------------
# 16 2019-10-25 18:29:20.126590 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8380854800936768
# the coefficient by vanila logistic regression  [[ 0.05123869  0.1271499  -0.17473309]]
# sampling ratio =  0.10006342701014832 ,reg =  0.001 , unlabeled-node accuracy =  0.8535274951071016
# labeled-node accuracy =  0.8861475449802526
# the aggregated accuracy =  0.8567915690866511
# -----------------
# ------------------------------------
#
# 17 2019-10-25 18:35:00.898727 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8317110655737705
# the coefficient by vanila logistic regression  [[ 0.05253236  0.12949381 -0.17801549]]
# sampling ratio =  0.09975361046057768 ,reg =  0.001 , unlabeled-node accuracy =  0.9785138837327148
# labeled-node accuracy =  0.9959159717297205
# the aggregated accuracy =  0.9802498048399688
# -----------------
# 17 2019-10-25 18:40:41.120851 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8321404176424668
# the coefficient by vanila logistic regression  [[ 0.05088933  0.12454779 -0.17183147]]
# sampling ratio =  0.10069037861046058 ,reg =  0.001 , unlabeled-node accuracy =  0.8457567578564744
# labeled-node accuracy =  0.8807510599636584
# the aggregated accuracy =  0.8492803473848556
# -----------------
# ------------------------------------
#
# 18 2019-10-25 18:45:43.634448 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8226117291178766
# the coefficient by vanila logistic regression  [[ 0.04934321  0.11988262 -0.16526702]]
# sampling ratio =  0.10091969164715066 ,reg =  0.001 , unlabeled-node accuracy =  0.9785185768048384
# labeled-node accuracy =  0.9958422973724286
# the aggregated accuracy =  0.980266881342701
# -----------------
# 18 2019-10-25 18:50:36.614812 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8230240046838407
# the coefficient by vanila logistic regression  [[ 0.04897925  0.11798812 -0.163158  ]]
# sampling ratio =  0.09955845042935207 ,reg =  0.001 , unlabeled-node accuracy =  0.8313668862043462
# labeled-node accuracy =  0.8721668177697189
# the aggregated accuracy =  0.8354288641686183
# -----------------
# ------------------------------------
#
# 19 2019-10-25 18:55:27.713180 use zero lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.8243754879000781
# the coefficient by vanila logistic regression  [[ 0.04921472  0.12020092 -0.16540401]]
# sampling ratio =  0.10011953551912568 ,reg =  0.001 , unlabeled-node accuracy =  0.9772310161326614
# labeled-node accuracy =  0.9962720206622646
# the aggregated accuracy =  0.9791373926619829
# -----------------
# 19 2019-10-25 19:01:10.400681 use previous lables
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:39: RuntimeWarning: overflow encountered in ubyte_scalars
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.824558450429352
# the coefficient by vanila logistic regression  [[ 0.0518833   0.12037046 -0.16807172]]
# sampling ratio =  0.10007562451209992 ,reg =  0.001 , unlabeled-node accuracy =  0.8312238917638257
# labeled-node accuracy =  0.8768739487604514
# the aggregated accuracy =  0.835792349726776
# -----------------
# ------------------------------------

# %% [markdown]
# So the best reg is 0.01 which its aggregated accuracy is 0.99.

# %%
def _get_lable(value):
    if value <= 0:
        return -1
    else:
        return 1

    
def _get_predicted_pixel_color(predicted_lable, true_lable):
    if predicted_lable != true_lable:
        # black
        return 0
    # white
    return 255

def _get_predicted_img():    
    w = np.load('w_0.010000_0.100000_0.npy')
    vanila_w = np.load('vanila_w_0.010000_0.100000.npy')

    height, width, band = img.shape

    predicted_img = np.zeros((height, width))
    predicted_vanila_img = np.zeros((height, width))

    lables = np.zeros((height, width))
    vanila_lables = np.zeros((height, width))

    i = 0
    for y in range(height):
        for x in range(width):
            lables[y, x] = _get_lable(np.dot(w[:, i], uc_X[:, i]))
            vanila_lables[y, x] = _get_lable(np.dot(vanila_w, uc_X[:, i]))

            predicted_img[y, x] = _get_predicted_pixel_color(lables[y, x], uc_y[i])
            predicted_vanila_img[y, x] = _get_predicted_pixel_color(vanila_lables[y, x], uc_y[i])

            i += 1
    return predicted_img, predicted_vanila_img, lables, vanila_lables

predicted_img, predicted_vanila_img, lables, vanila_lables = _get_predicted_img()

# %% [markdown]
# In the black and white image, white pixels have predicted correctly and black pixels have predicted wrongly by our method with reg=0.01.

# %%
# print('missed lables by out method for reg: 0.01')
# show_img_with_label(predicted_img)

# %% [markdown]
# In the black and white image, white pixels have predicted correctly and black pixels have predicted wrongly by vanila logistic regression.

# %%
# print('missed lables for vanila logistic regression')
# show_img_with_label(predicted_vanila_img)

# %% [markdown]
# Image shows the foreground image that our method has predicted with reg = 0.01.

# %%
print('foreground image for reg: 0.01')
show_img_with_label(img, lables)
# Out:
# foreground image for reg: 0.01

# %% [markdown]
# Image shows the foreground image that vanila logistic regression has predicted.

# %%
print('foreground image for vanila logistic Regression')
show_img_with_label(img, vanila_lables)
# Out:
# foreground image for vanila logistic Regression
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7ada3ac19340> in <module>
#       1 print('foreground image for vanila logistic Regression')
# ----> 2 show_img_with_label(img, vanila_lables)
#
# NameError: name 'show_img_with_label' is not defined

# %% [markdown]
# At the bellow image the white rectangular is selected as the sampling set.

# %%
# new_img = imageio.imread(img_file_name+ '.png')
# height, width, band = img.shape
# M_mtx = np.zeros((img.shape[0], img.shape[1]))
# M_mtx[50:200, 150:350] = 1
# 
# for y in range(height):
#     for x in range(width):
#         if M_mtx[y, x] == 1:
#             new_img[y, x] = (255, 255, 255)
#             
# show_img_with_label(new_img)
# 
# M = []
# for y in range(height):
#     for x in range(width):
#         M.append(1 if M_mtx[y, x] == 1 else 0)
# M = np.array(M)

# %%
# uc_non_acc, uc_acc = train(uc_graph, uc_X, uc_y, uc_opt_acc, 500, reg=[0.01], prob=prob, num_exps=1, M=M, is_plot=True, prefix="img",
#                                is_saved=True, compare_with_lr=True)
# 
# predicted_img, predicted_vanila_img, lables, vanila_lables = _get_predicted_img()
# 
# print('missed lables by our method for reg: 0.01')
# show_img_with_label(predicted_img)
# 
# print('missed lables by vanila logistic for reg: 0.01')
# show_img_with_label(predicted_vanila_img)
# Out:
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.6719904663829898
# the coefficient by vanila logistic regression  [[ 0.85489322 -0.9319281   0.29864161]]
# sampling ratio =  0.11657955583189228 ,reg =  0.01 , unlabeled-node accuracy =  0.4277754561916701
# labeled-node accuracy =  1.0
# the aggregated accuracy =  0.4944851393449524
# -----------------
# missed lables by our method for reg: 0.01
# missed lables by vanila logistic for reg: 0.01

# %% [markdown]
# Now we want to try separate sampling sets for foreground and background.

# %%
# new_img = imageio.imread(img_file_name+ '.png')
# height, width, band = img.shape
# M_mtx = np.zeros((img.shape[0], img.shape[1]))
# M_mtx[50:150, 20:120] = 1
# M_mtx[100:180, 220:320] = 1
# 
# for y in range(height):
#     for x in range(width):
#         if M_mtx[y, x] == 1:
#             new_img[y, x] = (255, 255, 255)
#             
# show_img_with_label(new_img)
# 
# M = []
# for y in range(height):
#     for x in range(width):
#         M.append(1 if M_mtx[y, x] == 1 else 0)
# M = np.array(M)

# %%
# uc_non_acc, uc_acc = train(uc_graph, uc_X, uc_y, uc_opt_acc, 500, reg=[0.01], prob=prob, num_exps=1, M=M, is_plot=True, prefix="img",
#                                is_saved=True, compare_with_lr=True)
# 
# predicted_img, predicted_vanila_img, lables, vanila_lables = _get_predicted_img()
# 
# print('missed lables by our method for reg: 0.01')
# show_img_with_label(predicted_img)
# 
# print('missed lables by vanila logistic for reg: 0.01')
# show_img_with_label(predicted_vanila_img)
# Out:
# /anaconda3/envs/DeepRL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# the accuracy by vanila logistic regression  0.6719904663829898
# the coefficient by vanila logistic regression  [[ 0.85489322 -0.9319281   0.29864161]]
# sampling ratio =  0.11657955583189228 ,reg =  0.01 , unlabeled-node accuracy =  0.4277754561916701
# labeled-node accuracy =  1.0
# the aggregated accuracy =  0.4944851393449524
# -----------------
# missed lables by our method for reg: 0.01
# missed lables by vanila logistic for reg: 0.01
